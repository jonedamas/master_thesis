# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys

sys.path.insert(0, r'c:\Users\joneh\master_thesis\src')
from main_utils import *

# %%
start_date, end_date = '2003-12-31', '2023-12-31'

ticker = 'CL=F'

df = yf.download(ticker, start=start_date, end=end_date, progress=False)

display(df)

df['Adj Close'].plot()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2003-12-31  32.880001  33.200001  32.299999  32.520000  32.520000   66694
# 2004-01-05  32.400002  33.950001  32.270000  33.779999  33.779999  105704
# 2004-01-06  33.759998  34.349998  33.299999  33.700001  33.700001  103405
# 2004-01-07  33.680000  33.889999  33.049999  33.619999  33.619999   81675
# 2004-01-08  33.650002  34.000000  33.400002  33.980000  33.980000   92709
# ...               ...        ...        ...        ...        ...     ...
# 2023-12-22  73.910004  74.980003  73.389999  73.559998  73.559998  222600
# 2023-12-26  73.559998  76.180000  73.129997  75.570000  75.570000  208715
# 2023-12-27  75.320000  75.660004  73.769997  74.110001  74.110001  253323
# 2023-12-28  73.800003  74.400002  71.720001  71.769997  71.769997  262748
# 2023-12-29  71.989998  72.620003  71.250000  71.650002  71.650002  214486
#
# [5029 rows x 6 columns]
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Save data

# %%
# Enter filename here:
file_name = 'CL=F_20years.csv'
# Enter relative path for saving the file:
relative_path = 'data/time_series/YahooFinance/'

df.to_csv(save_path(relative_path, file_name), index=False)
